# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5243, 3082, 12, 6, 195, 2, 3136, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    """
    Generate a single batch of words and corresponding labels.
    """
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid: # if target is still part of targets_to_avoid
                target = random.randint(0, span - 1) # regenerate target
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'anarchism', 'term', 'term', 'originated', 'as', 'of']

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.
context_window = 2*skip_window
sum_ids = np.repeat(np.arange(batch_size/context_window),context_window)

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size/context_window, 1])
    segment_ids = tf.constant(sum_ids, dtype=tf.int32)
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
#     softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
#                              stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]),trainable=False)

    # Model.
    # Look up embeddings for inputs.
    embed = tf.segment_mean(tf.nn.embedding_lookup(embeddings, train_dataset),segment_ids)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(embeddings, softmax_biases, embed,
                                   train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_labels, batch_data = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : np.squeeze(batch_data), train_labels : batch_labels[::(context_window)][:,None]}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 13.617647
# Nearest to is: touched, enhances, inferiority, ricans, unopposed, fields, afghanistan, elegance,
# Nearest to there: merchants, magical, fitting, breakdance, harshly, data, macroeconomics, energetic,
# Nearest to than: scanner, manifestation, diachronic, incorrectly, design, goku, thermopylae, reservoir,
# Nearest to united: magnificence, palaces, pluto, hubbard, hereford, michell, guerilla, captors,
# Nearest to new: proverb, cisc, minister, bothnia, rags, ip, chung, li,
# Nearest to if: belong, shahi, shortfalls, randall, precepts, nicaea, darrell, analects,
# Nearest to who: knocked, icebergs, shari, specializing, samara, szabo, attacks, printout,
# Nearest to when: dictate, appointment, blaxploitation, collared, obituary, triadic, jagiello, somehow,
# Nearest to called: what, boldness, printable, hertogenbosch, instructs, insuring, inhibited, chestnuts,
# Nearest to zero: trumps, suffixes, inapplicable, vdash, liberty, promised, scaling, upholding,
# Nearest to two: liable, incurable, faye, breeze, doe, talisman, logistics, overthrew,
# Nearest to more: sinope, samson, broccoli, naiste, ramirez, axiom, cherry, floresiensis,
# Nearest to not: greater, strategically, gaff, argumentative, elas, rond, active, scottsdale,
# Nearest to one: percentage, mico, gladiator, genet, intakes, viewpoint, banished, believe,
# Nearest to s: krag, yuma, accompanied, qq, paramilitaries, arrogant, sickly, accusations,
# Nearest to system: escher, francesco, ellipsoid, mites, saterland, leonel, handling, dojos,
# Average loss at step 2000: 6.161996
# Average loss at step 4000: 5.142353
# Average loss at step 6000: 4.905193
# Average loss at step 8000: 4.751925
# Average loss at step 10000: 4.383796
# Nearest to is: it, now, which, are, there, was, a, being,
# Nearest to there: are, is, was, were, it, still, often, which,
# Nearest to than: more, rather, less, other, a, with, any, under,
# Nearest to united: states, kingdom, nations, the, after, government, member, world,
# Nearest to new: the, of, a, for, and, non, in, state,
# Nearest to if: even, you, however, that, when, not, they, only,
# Nearest to who: had, he, were, are, was, that, they, have,
# Nearest to when: the, time, however, and, one, in, he, but,
# Nearest to called: so, sometimes, it, are, is, now, UNK, also,
# Nearest to zero: two, four, three, five, one, eight, six, seven,
# Nearest to two: one, five, three, zero, four, eight, six, seven,
# Nearest to more: than, less, a, rather, other, with, for, and,
# Nearest to not: did, do, is, does, always, they, being, was,
# Nearest to one: two, eight, five, six, nine, three, four, in,
# Nearest to s: u, country, people, first, the, and, UNK, of,
# Nearest to system: legal, is, which, and, for, the, a, systems,
# Average loss at step 12000: 4.290844
# Average loss at step 14000: 4.412880
# Average loss at step 16000: 4.321006
# Average loss at step 18000: 4.253895
# Average loss at step 20000: 4.232855
# Nearest to is: it, was, not, also, this, which, he, are,
# Nearest to there: are, were, is, they, often, it, usually, still,
# Nearest to than: rather, more, less, or, a, but, even, just,
# Nearest to united: states, kingdom, nations, following, the, same, us, church,
# Nearest to new: york, city, jersey, a, the, of, testament, state,
# Nearest to if: that, it, you, even, however, is, time, just,
# Nearest to who: those, have, he, had, would, were, that, could,
# Nearest to when: the, UNK, that, only, he, and, but, three,
# Nearest to called: sometimes, is, also, are, so, often, UNK, was,
# Nearest to zero: two, four, six, five, eight, seven, three, nine,
# Nearest to two: four, three, five, zero, one, six, seven, eight,
# Nearest to more: much, than, or, a, UNK, and, are, most,
# Nearest to not: did, is, do, are, it, generally, considered, always,
# Nearest to one: nine, four, five, two, seven, six, three, eight,
# Nearest to s: u, and, man, book, children, king, the, women,
# Nearest to system: expert, systems, is, an, the, this, it, allows,
# Average loss at step 22000: 4.120841
# Average loss at step 24000: 3.989752
# Average loss at step 26000: 3.878198
# Average loss at step 28000: 3.983974
# Average loss at step 30000: 3.848117
# Nearest to is: it, was, there, this, considered, which, are, a,
# Nearest to there: are, is, now, it, they, sometimes, he, was,
# Nearest to than: more, rather, less, much, other, or, any, larger,
# Nearest to united: states, kingdom, nations, the, following, army, during, same,
# Nearest to new: york, zealand, city, a, in, the, jersey, england,
# Nearest to if: where, when, that, i, it, is, the, you,
# Nearest to who: had, he, were, wrote, was, they, and, could,
# Nearest to when: he, time, if, that, she, it, but, was,
# Nearest to called: is, UNK, now, are, often, so, sometimes, and,
# Nearest to zero: four, two, five, six, three, seven, eight, nine,
# Nearest to two: zero, three, six, five, four, seven, one, nine,
# Nearest to more: than, less, much, most, a, common, for, or,
# Nearest to not: did, do, does, could, would, is, have, will,
# Nearest to one: nine, eight, five, three, seven, six, four, two,
# Nearest to s: UNK, and, u, women, the, death, life, father,
# Nearest to system: a, the, for, of, and, in, is, this,
# Average loss at step 32000: 3.886744
# Average loss at step 34000: 3.849665
# Average loss at step 36000: 3.771030
# Average loss at step 38000: 3.933021
# Average loss at step 40000: 3.863210
# Nearest to is: it, was, god, which, not, a, there, that,
# Nearest to there: are, is, it, which, was, were, they, now,
# Nearest to than: rather, more, less, greater, larger, better, a, faster,
# Nearest to united: states, kingdom, nations, the, church, same, last, nation,
# Nearest to new: york, zealand, a, jersey, testament, the, whole, form,
# Nearest to if: even, it, however, that, we, and, is, though,
# Nearest to who: those, were, had, he, are, people, which, also,
# Nearest to when: he, the, however, and, but, if, it, world,
# Nearest to called: sometimes, often, is, also, UNK, was, are, simply,
# Nearest to zero: five, four, two, six, three, eight, seven, one,
# Nearest to two: four, zero, six, one, five, three, seven, eight,
# Nearest to more: less, than, much, a, very, most, likely, often,
# Nearest to not: do, could, is, actually, be, did, only, it,
# Nearest to one: six, three, seven, eight, two, nine, four, five,
# Nearest to s: u, and, UNK, the, world, god, children, first,
# Nearest to system: and, solar, for, control, management, a, this, the,
# Average loss at step 42000: 3.773614
# Average loss at step 44000: 3.552322
# Average loss at step 46000: 3.772412
# Average loss at step 48000: 3.860482
# Average loss at step 50000: 3.840990
# Nearest to is: it, was, which, and, he, a, that, called,
# Nearest to there: are, is, they, it, that, he, now, although,
# Nearest to than: more, rather, less, any, smaller, greater, faster, larger,
# Nearest to united: states, kingdom, nations, constitution, netherlands, the, island, world,
# Nearest to new: york, zealand, a, the, city, jersey, team, of,
# Nearest to if: when, you, where, however, that, because, and, but,
# Nearest to who: had, were, he, people, man, was, played, which,
# Nearest to when: he, if, it, that, and, is, because, however,
# Nearest to called: is, UNK, now, also, sometimes, and, are, it,
# Nearest to zero: two, five, three, eight, six, seven, four, one,
# Nearest to two: zero, one, five, three, nine, four, six, seven,
# Nearest to more: than, much, less, even, a, very, common, or,
# Nearest to not: do, does, did, is, yet, could, only, generally,
# Nearest to one: two, nine, five, three, zero, seven, eight, four,
# Nearest to s: law, u, and, UNK, team, the, men, women,
# Nearest to system: for, and, which, systems, the, this, game, a,
# Average loss at step 52000: 3.854679
# Average loss at step 54000: 3.780679
# Average loss at step 56000: 3.787897
# Average loss at step 58000: 3.528736
# Average loss at step 60000: 3.716340
# Nearest to is: it, there, was, what, now, that, are, which,
# Nearest to there: are, is, were, was, they, it, which, he,
# Nearest to than: more, rather, less, even, smaller, any, lower, greater,
# Nearest to united: states, kingdom, nations, provinces, the, constitution, following, city,
# Nearest to new: a, the, york, city, and, of, town, world,
# Nearest to if: that, it, even, they, when, what, though, not,
# Nearest to who: he, was, had, people, those, which, would, have,
# Nearest to when: he, it, but, that, the, before, if, however,
# Nearest to called: so, is, sometimes, often, also, UNK, it, was,
# Nearest to zero: seven, five, two, four, six, eight, three, nine,
# Nearest to two: seven, four, five, eight, nine, three, six, one,
# Nearest to more: than, less, rather, even, much, common, most, a,
# Nearest to not: does, do, did, is, it, were, was, they,
# Nearest to one: nine, eight, two, seven, six, four, five, three,
# Nearest to s: UNK, u, and, country, the, government, hungary, of,
# Nearest to system: this, and, systems, legal, the, a, power, or,
# Average loss at step 62000: 3.772896
# Average loss at step 64000: 3.643094
# Average loss at step 66000: 3.656385
# Average loss at step 68000: 3.712748
# Average loss at step 70000: 3.709935
# Nearest to is: it, was, now, there, are, that, a, often,
# Nearest to there: are, is, it, still, now, they, although, which,
# Nearest to than: rather, more, less, faster, smaller, larger, much, or,
# Nearest to united: states, kingdom, nations, nation, netherlands, provinces, the, city,
# Nearest to new: a, york, city, the, of, in, government, first,
# Nearest to if: that, though, it, only, even, but, so, when,
# Nearest to who: those, people, were, had, they, wrote, he, are,
# Nearest to when: but, only, and, it, he, if, that, time,
# Nearest to called: is, sometimes, now, so, UNK, was, also, often,
# Nearest to zero: five, four, two, three, eight, seven, six, nine,
# Nearest to two: one, five, three, four, zero, eight, seven, six,
# Nearest to more: than, less, difficult, little, a, even, very, or,
# Nearest to not: did, does, do, is, only, was, are, required,
# Nearest to one: nine, two, eight, six, three, seven, four, five,
# Nearest to s: u, UNK, death, and, father, the, his, country,
# Nearest to system: state, the, writing, for, a, legal, which, this,
# Average loss at step 72000: 3.715043
# Average loss at step 74000: 3.713443
# Average loss at step 76000: 3.599346
# Average loss at step 78000: 3.382194
# Average loss at step 80000: 3.615977
# Nearest to is: it, was, which, a, there, often, this, that,
# Nearest to there: are, is, which, that, they, were, it, was,
# Nearest to than: rather, more, less, larger, lower, faster, higher, smaller,
# Nearest to united: states, kingdom, nations, the, same, nation, following, romans,
# Nearest to new: york, a, jersey, the, zealand, testament, of, uses,
# Nearest to if: even, when, only, that, it, the, we, but,
# Nearest to who: had, died, were, people, individuals, children, they, men,
# Nearest to when: even, however, but, if, they, he, it, time,
# Nearest to called: so, also, sometimes, is, UNK, often, are, it,
# Nearest to zero: five, eight, four, two, seven, six, three, nine,
# Nearest to two: three, zero, one, four, five, eight, six, seven,
# Nearest to more: less, than, much, most, difficult, common, or, so,
# Nearest to not: do, does, did, would, be, actually, could, but,
# Nearest to one: nine, eight, six, two, four, three, seven, five,
# Nearest to s: u, and, women, UNK, the, first, sister, his,
# Nearest to system: solar, systems, legal, the, operating, writing, of, a,
# Average loss at step 82000: 3.506230
# Average loss at step 84000: 3.590837
# Average loss at step 86000: 3.604106
# Average loss at step 88000: 3.527436
# Average loss at step 90000: 3.422888
# Nearest to is: was, it, now, also, which, often, he, a,
# Nearest to there: are, were, is, they, was, often, sometimes, it,
# Nearest to than: more, rather, less, or, smaller, fewer, other, faster,
# Nearest to united: states, kingdom, nations, the, first, same, following, arab,
# Nearest to new: york, year, city, the, zealand, jersey, a, of,
# Nearest to if: you, even, when, that, what, only, they, it,
# Nearest to who: was, he, had, also, were, is, people, women,
# Nearest to when: he, if, however, although, where, at, was, it,
# Nearest to called: is, so, often, sometimes, also, UNK, was, now,
# Nearest to zero: two, five, six, four, three, seven, eight, nine,
# Nearest to two: zero, three, four, six, five, seven, eight, nine,
# Nearest to more: than, less, or, a, for, difficult, even, recently,
# Nearest to not: did, do, be, only, yet, does, always, was,
# Nearest to one: nine, eight, four, five, seven, three, six, two,
# Nearest to s: u, and, UNK, the, of, women, work, father,
# Nearest to system: systems, the, of, which, theory, writing, this, a,
# Average loss at step 92000: 2.725642
# Average loss at step 94000: 3.248407
# Average loss at step 96000: 3.184290
# Average loss at step 98000: 3.404102
# Average loss at step 100000: 3.495783
# Nearest to is: there, it, was, which, not, a, this, but,
# Nearest to there: is, are, it, which, but, was, that, he,
# Nearest to than: more, less, rather, better, much, or, greater, faster,
# Nearest to united: states, kingdom, nations, constitution, the, senate, city, romans,
# Nearest to new: york, zealand, jersey, the, mexico, city, england, a,
# Nearest to if: you, that, but, when, even, only, they, we,
# Nearest to who: had, was, he, those, were, also, played, produced,
# Nearest to when: he, however, but, time, that, though, where, if,
# Nearest to called: sometimes, is, UNK, also, often, so, was, a,
# Nearest to zero: two, five, three, four, eight, six, seven, nine,
# Nearest to two: zero, five, three, four, eight, one, six, seven,
# Nearest to more: than, less, much, a, very, is, or, difficult,
# Nearest to not: only, is, did, does, be, could, always, usually,
# Nearest to one: nine, eight, seven, six, four, five, three, two,
# Nearest to s: u, death, UNK, children, john, his, first, father,
# Nearest to system: systems, the, power, a, of, and, court, legal,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
